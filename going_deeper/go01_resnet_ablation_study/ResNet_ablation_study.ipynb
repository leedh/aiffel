# %% [markdown]
# # 프로젝트: 없다면 어떻게 될까? (ResNet Ablation Study)
# |평가문항|상세기준|
# |:---|:---|
# |1. ResNet-34, ResNet-50 모델 구현이 정상적으로 진행되었는가?|블록함수 구현이 제대로 진행되었으며 구현한 모델의 summary가 예상된 형태로 출력되었다.|
# |2. 구현한 ResNet 모델을 활용하여 Image Classification 모델 훈련이 가능한가?|tensorflow-datasets에서 제공하는 cats_vs_dogs 데이터셋으로 학습 진행 시 loss가 감소하는 것이 확인되었다.|
# |3. Ablation Study 결과가 바른 포맷으로 제출되었는가?|ResNet-34, ResNet-50 각각 plain모델과 residual모델을 동일한 epoch만큼 학습시켰을 때의 validation accuracy 기준으로 Ablation Study 결과표가 작성되었다.|

# %% [markdown]
# ##  1. Set up & Preprocessing

# %%
# !pip install --upgrade tensorflow_datasets # 4.9.3 최신버전으로 업데이트

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds # tensorflow 데이터셋

print(tf.__version__)
print(np.__version__)
print(tfds.__version__)
# Out:
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2.15.0
# 1.26.4
# 4.4.0

# %%
# Tensorflow가 활용할 GPU가 장착되어 있는지 확인
tf.config.list_physical_devices('GPU')
# Out:
# []

# %% [markdown]
# #### 옵션1. tensorflow_datasets에서 불러오기

# %%
import urllib3
urllib3.disable_warnings()

#tfds.disable_progress_bar()   # 이 주석을 풀면 데이터셋 다운로드과정의 프로그레스바가 나타나지 않습니다.

(ds_train, ds_test), ds_info = tfds.load(
    'cats_vs_dogs',
    split=['train[:80%]', 'train[80%:]'],
    as_supervised=True,
    shuffle_files=True,
    with_info=True,
)

# Tensorflow 데이터셋을 로드 후 feature 정보 확인
print(ds_info.features)

# 데이터의 개수 확인
print(tf.data.experimental.cardinality(ds_train))
print(tf.data.experimental.cardinality(ds_test))
# Out:
# Downloading and preparing dataset 786.68 MiB (download: 786.68 MiB, generated: Unknown size, total: 786.68 MiB) to /aiffel/tensorflow_datasets/cats_vs_dogs/4.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# ---------------------------------------------------------------------------
# DownloadError                             Traceback (most recent call last)
# /tmp/ipykernel_380/2968147293.py in <module>
#       4 #tfds.disable_progress_bar()   # 이 주석을 풀면 데이터셋 다운로드과정의 프로그레스바가 나타나지 않습니다.
#       5
# ----> 6 (ds_train, ds_test), ds_info = tfds.load(
#       7     'cats_vs_dogs',
#       8     split=['train[:80%]', 'train[80%:]'],
#
# /opt/conda/lib/python3.9/site-packages/tensorflow_datasets/core/load.py in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     316   if download:
#     317     download_and_prepare_kwargs = download_and_prepare_kwargs or {}
# --> 318     dbuilder.download_and_prepare(**download_and_prepare_kwargs)
#     319
#     320   if as_dataset_kwargs is None:
#
# /opt/conda/lib/python3.9/site-packages/tensorflow_datasets/core/dataset_builder.py in download_and_prepare(self, download_dir, download_config)
#     437           # Old version of TF are not os.PathLike compatible
#     438           with tf_compat.mock_gfile_pathlike():
# --> 439             self._download_and_prepare(
#     440                 dl_manager=dl_manager,
#     441                 download_config=download_config,
#
# /opt/conda/lib/python3.9/site-packages/tensorflow_datasets/core/dataset_builder.py in _download_and_prepare(self, dl_manager, download_config)
#    1111       else:
#    1112         optional_pipeline_kwargs = {}
# -> 1113       split_generators = self._split_generators(  # pylint: disable=unexpected-keyword-arg
#    1114           dl_manager, **optional_pipeline_kwargs)
#    1115       # TODO(tfds): Could be removed once all datasets are migrated.
#
# /opt/conda/lib/python3.9/site-packages/tensorflow_datasets/image_classification/cats_vs_dogs.py in _split_generators(self, dl_manager)
#      68
#      69   def _split_generators(self, dl_manager):
# ---> 70     path = dl_manager.download(_URL)
#      71
#      72     # There is no predefined train/val/test split for this dataset.
#
# /opt/conda/lib/python3.9/site-packages/tensorflow_datasets/core/download/download_manager.py in download(self, url_or_urls)
#     547     # Add progress bar to follow the download state
#     548     with self._downloader.tqdm():
# --> 549       return _map_promise(self._download, url_or_urls)
#     550
#     551   def iter_archive(
#
# /opt/conda/lib/python3.9/site-packages/tensorflow_datasets/core/download/download_manager.py in _map_promise(map_fn, all_inputs)
#     765   """Map the function into each element and resolve the promise."""
#     766   all_promises = tf.nest.map_structure(map_fn, all_inputs)  # Apply the function
# --> 767   res = tf.nest.map_structure(lambda p: p.get(), all_promises)  # Wait promises
#     768
#     769   return res
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     629     ValueError: If wrong keyword arguments are provided.
#     630   """
# --> 631   return nest_util.map_structure(
#     632       nest_util.Modality.CORE, func, *structure, **kwargs
#     633   )
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/util/nest_util.py in map_structure(modality, func, *structure, **kwargs)
#    1064   """
#    1065   if modality == Modality.CORE:
# -> 1066     return _tf_core_map_structure(func, *structure, **kwargs)
#    1067   elif modality == Modality.DATA:
#    1068     return _tf_data_map_structure(func, *structure, **kwargs)
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/util/nest_util.py in _tf_core_map_structure(func, *structure, **kwargs)
#    1104   return _tf_core_pack_sequence_as(
#    1105       structure[0],
# -> 1106       [func(*x) for x in entries],
#    1107       expand_composites=expand_composites,
#    1108   )
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/util/nest_util.py in <listcomp>(.0)
#    1104   return _tf_core_pack_sequence_as(
#    1105       structure[0],
# -> 1106       [func(*x) for x in entries],
#    1107       expand_composites=expand_composites,
#    1108   )
#
# /opt/conda/lib/python3.9/site-packages/tensorflow_datasets/core/download/download_manager.py in <lambda>(p)
#     765   """Map the function into each element and resolve the promise."""
#     766   all_promises = tf.nest.map_structure(map_fn, all_inputs)  # Apply the function
# --> 767   res = tf.nest.map_structure(lambda p: p.get(), all_promises)  # Wait promises
#     768
#     769   return res
#
# /opt/conda/lib/python3.9/site-packages/promise/promise.py in get(self, timeout)
#     510         target = self._target()
#     511         self._wait(timeout or DEFAULT_TIMEOUT)
# --> 512         return self._target_settled_value(_raise=True)
#     513
#     514     def _target_settled_value(self, _raise=False):
#
# /opt/conda/lib/python3.9/site-packages/promise/promise.py in _target_settled_value(self, _raise)
#     514     def _target_settled_value(self, _raise=False):
#     515         # type: (bool) -> Any
# --> 516         return self._target()._settled_value(_raise)
#     517
#     518     _value = _reason = _target_settled_value
#
# /opt/conda/lib/python3.9/site-packages/promise/promise.py in _settled_value(self, _raise)
#     224             if _raise:
#     225                 raise_val = self._fulfillment_handler0
# --> 226                 reraise(type(raise_val), raise_val, self._traceback)
#     227             return self._fulfillment_handler0
#     228
#
# /opt/conda/lib/python3.9/site-packages/six.py in reraise(tp, value, tb)
#     717             if value.__traceback__ is not tb:
#     718                 raise value.with_traceback(tb)
# --> 719             raise value
#     720         finally:
#     721             value = None
#
# /opt/conda/lib/python3.9/site-packages/promise/promise.py in handle_future_result(future)
#     842         # type: (Any) -> None
#     843         try:
# --> 844             resolve(future.result())
#     845         except Exception as e:
#     846             tb = exc_info()[2]
#
# /opt/conda/lib/python3.9/concurrent/futures/_base.py in result(self, timeout)
#     436                     raise CancelledError()
#     437                 elif self._state == FINISHED:
# --> 438                     return self.__get_result()
#     439
#     440                 self._condition.wait(timeout)
#
# /opt/conda/lib/python3.9/concurrent/futures/_base.py in __get_result(self)
#     388         if self._exception:
#     389             try:
# --> 390                 raise self._exception
#     391             finally:
#     392                 # Break a reference cycle with the exception in self._exception
#
# /opt/conda/lib/python3.9/concurrent/futures/thread.py in run(self)
#      50
#      51         try:
# ---> 52             result = self.fn(*self.args, **self.kwargs)
#      53         except BaseException as exc:
#      54             self.future.set_exception(exc)
#
# /opt/conda/lib/python3.9/site-packages/tensorflow_datasets/core/download/downloader.py in _sync_download(self, url, destination_path, verify)
#     214       pass
#     215
# --> 216     with _open_url(url, verify=verify) as (response, iter_content):
#     217       fname = _get_filename(response)
#     218       path = os.path.join(destination_path, fname)
#
# /opt/conda/lib/python3.9/contextlib.py in __enter__(self)
#     117         del self.args, self.kwds, self.func
#     118         try:
# --> 119             return next(self.gen)
#     120         except StopIteration:
#     121             raise RuntimeError("generator didn't yield") from None
#
# /opt/conda/lib/python3.9/site-packages/tensorflow_datasets/core/download/downloader.py in _open_with_requests(url, **kwargs)
#     276       url = _get_drive_url(url, session)
#     277     with session.get(url, stream=True, **kwargs) as response:
# --> 278       _assert_status(response)
#     279       yield (response, response.iter_content(chunk_size=io.DEFAULT_BUFFER_SIZE))
#     280
#
# /opt/conda/lib/python3.9/site-packages/tensorflow_datasets/core/download/downloader.py in _assert_status(response)
#     307   """Ensure the URL response is 200."""
#     308   if response.status_code != 200:
# --> 309     raise DownloadError('Failed to get url {}. HTTP code: {}.'.format(
#     310         response.url, response.status_code))
#
# DownloadError: Failed to get url https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_3367a.zip. HTTP code: 404.

# %%
# 이미지의 표현이 0과 1 사이로 들어오는 정규화 코드
def normalize_and_resize_img(image, label):
    """Normalizes images: `uint8` -> `float32`."""
    image = tf.image.resize(image, (224,224))
    return tf.cast(image, tf.float32) / 255., label

def apply_normalize_on_dataset(ds, is_test=False, batch_size=16):
    ds = ds.map(
        normalize_and_resize_img,
        num_parallel_calls=1
    )
    ds = ds.batch(batch_size)
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
num_classes = ds_info.features["label"].num_classes
print(num_classes)

# %%
ds_info.features["label"].names

# %%
# 데이터셋 일부 시각화
fig = tfds.show_examples(ds_train, ds_info)

# %%
# 데이터셋 일부 시각화
fig = tfds.show_examples(ds_test, ds_info)

# %% [markdown]
# #### 옵션2. kaggle에서 다운로드 받은 데이터셋 불러오기
# 데이터셋 링크: https://www.kaggle.com/competitions/dogs-vs-cats/data

# %%
import os, shutil, pathlib

#train / val /test dataset split
#train에 이미 cat0~cat12499 fname있다. (dog도 마찬가지)

original_dir = pathlib.Path('train') # 원본 데이터셋이 압축 해제되어 있는 디렉토리 경로
new_base_dir = pathlib.Path('cat_vs_dog_dataset') # 서브셋 데이터를 저정할 디렉토리

def make_dataset(subset_name, start_index, end_index):
    for category in ('cat', 'dog'):
        new_dir = new_base_dir / subset_name / category
        os.makedirs(new_dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir/fname, dst = new_dir/fname)
            
make_dataset('train', 0, 5000)
make_dataset('val', 5000, 7500)
make_dataset('test', 7500, 12499)

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory('cat_vs_dog_data/train',
                                            image_size = (224,224),
                                            batch_size = 32)

val_dataset = image_dataset_from_directory('cat_vs_dog_data/val',
                                            image_size = (224,224),
                                            batch_size = 32)

test_dataset = image_dataset_from_directory('cat_vs_dog_data/test',
                                            image_size = (224,224),
                                            batch_size = 32)

# %% [markdown]
# ## 2. Model building

# %% [markdown]
# ### building block 만들기

# %%
# function for building VGG Block

def build_resnet_block(input_layer,
                    num_cnn=3,
                    channel=64,
                    block_num=1,
                    is_50=False
                   ):
    # 입력 레이어
    x = input_layer

    # conv 레이어
    if is_50 == False: # ResNet34
        # shortcut
        shortcut = keras.layers.Conv2D(
            filters=channel,
            kernel_size=(1,1)
        )(input_layer)

        # 디폴트 3개 CNN 레이어
        for cnn_num in range(num_cnn):
            x = keras.layers.Conv2D(
                    filters=channel,
                    kernel_size=(3,3),
                    padding='same',
                    kernel_initializer='he_normal',
                    name=f'block{block_num}_conv{cnn_num}_1'
                )(x)
            x = keras.layers.BatchNormalization()(x)
            x = keras.layers.Activation('relu')(x)
            x = keras.layers.Conv2D(
                    filters=channel,
                    kernel_size=(3,3),
                    padding='same',
                    kernel_initializer='he_normal',
                    name=f'block{block_num}_conv{cnn_num}_2'
                )(x)
            x = keras.layers.BatchNormalization()(x)

            # f(x) + x
            x = keras.layers.Add(name=f'block{block_num}_add_{cnn_num}')([shortcut, x])
            x = keras.layers.Activation("relu", name=f'block{block_num}_out_{cnn_num}')(x)


    else: #ResNet50
        #shortcut
        shortcut = keras.layers.Conv2D(
                filters=channel*4,
                kernel_size=(1,1)
            )(input_layer)

        # 디폴트 3개 CNN 레이어
        for cnn_num in range(num_cnn):

            # 1x1 CNN 레이어
            x = keras.layers.Conv2D(
                        filters=channel,
                        kernel_size=(1,1),
                        kernel_initializer='he_normal',
                        padding='same',
                        name=f'block{block_num}_conv{cnn_num}_1x1'
                    )(x)

            x = keras.layers.BatchNormalization()(x)
            x = keras.layers.Activation('relu')(x)

            # 3x3 CNN 레이어
            x = keras.layers.Conv2D(
                        filters=channel,
                        kernel_size=(3,3),
                        kernel_initializer='he_normal',
                        padding='same',
                        name=f'block{block_num}_conv{cnn_num}_3x3'
                    )(x)

            x = keras.layers.BatchNormalization()(x)
            x = keras.layers.Activation('relu')(x)


            # 1x1 CNN 레이어
            x = keras.layers.Conv2D(
                filters=channel*4,
                kernel_size=(1,1),
                activation='relu',
                kernel_initializer='he_normal',
                padding='same',
                name=f'block{block_num}_conv{cnn_num}_1x1_2'
            )(x)

            # 마지막 batch normalization
            x = keras.layers.BatchNormalization()(x)

            # f(x) + x
            x = keras.layers.Add(name=f'block{block_num}_add_{cnn_num}')([shortcut, x])
            x = keras.layers.Activation("relu", name=f'block{block_num}_out_{cnn_num}')(x)
    return x

# %%
# block 생성 테스트
resnet_input_layer = keras.layers.Input(shape=(32,32,3))   # 입력 레이어 생성
resnet_block_output = build_resnet_block(resnet_input_layer)    # ResNet 블록 생성

# %%
# 블록 1개짜리 model 생성
model = keras.Model(inputs=resnet_input_layer, outputs=resnet_block_output)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  block1_conv0_1 (Conv2D)     (None, 32, 32, 64)           1792      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 32, 32, 64)           256       ['block1_conv0_1[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 32, 32, 64)           0         ['batch_normalization[0][0]']
#
#  block1_conv0_2 (Conv2D)     (None, 32, 32, 64)           36928     ['activation[0][0]']
#
#  conv2d (Conv2D)             (None, 32, 32, 64)           256       ['input_1[0][0]']
#
#  batch_normalization_1 (Bat  (None, 32, 32, 64)           256       ['block1_conv0_2[0][0]']
#  chNormalization)
#
#  block1_add_0 (Add)          (None, 32, 32, 64)           0         ['conv2d[0][0]',
#                                                                      'batch_normalization_1[0][0]'
#                                                                     ]
#
#  block1_out_0 (Activation)   (None, 32, 32, 64)           0         ['block1_add_0[0][0]']
#
#  block1_conv1_1 (Conv2D)     (None, 32, 32, 64)           36928     ['block1_out_0[0][0]']
#
#  batch_normalization_2 (Bat  (None, 32, 32, 64)           256       ['block1_conv1_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 32, 32, 64)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  block1_conv1_2 (Conv2D)     (None, 32, 32, 64)           36928     ['activation_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 32, 32, 64)           256       ['block1_conv1_2[0][0]']
#  chNormalization)
#
#  block1_add_1 (Add)          (None, 32, 32, 64)           0         ['conv2d[0][0]',
#                                                                      'batch_normalization_3[0][0]'
#                                                                     ]
#
#  block1_out_1 (Activation)   (None, 32, 32, 64)           0         ['block1_add_1[0][0]']
#
#  block1_conv2_1 (Conv2D)     (None, 32, 32, 64)           36928     ['block1_out_1[0][0]']
#
#  batch_normalization_4 (Bat  (None, 32, 32, 64)           256       ['block1_conv2_1[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 32, 32, 64)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  block1_conv2_2 (Conv2D)     (None, 32, 32, 64)           36928     ['activation_2[0][0]']
#
#  batch_normalization_5 (Bat  (None, 32, 32, 64)           256       ['block1_conv2_2[0][0]']
#  chNormalization)
#
#  block1_add_2 (Add)          (None, 32, 32, 64)           0         ['conv2d[0][0]',
#                                                                      'batch_normalization_5[0][0]'
#                                                                     ]
#
#  block1_out_2 (Activation)   (None, 32, 32, 64)           0         ['block1_add_2[0][0]']
#
# ==================================================================================================
# Total params: 188224 (735.25 KB)
# Trainable params: 187456 (732.25 KB)
# Non-trainable params: 768 (3.00 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ### ResNet 모델 만들기

# %%
# NesNet 모델 자체를 생성하는 함수
def build_resnet(input_shape=(32,32,3),
              num_cnn_list=[3,4,6,3],
              channel_list=[64,128,256,512],
              num_classes=num_classes,
              is_50=False):

    assert len(num_cnn_list) == len(channel_list) #모델을 만들기 전에 config list들이 같은 길이인지 확인합니다.

    input_layer = keras.layers.Input(shape=input_shape)  # input layer를 만들어둡니다.
#     output = input_layer

    # 첫 번째 Conv 레이어
    x = keras.layers.Conv2D(
        filters=64,
        kernel_size=(7,7),
        strides=2
    )(input_layer)

    # Max Pooling 레이어
    output = keras.layers.MaxPooling2D(
        pool_size=(3, 3),
        strides=2
    )(x)

    # config list들의 길이만큼 반복해서 두 번째 - 다섯 번째 Conv 블록을 생성
    for i, (num_cnn, channel) in enumerate(zip(num_cnn_list, channel_list)):
        output = build_resnet_block(
            output,
            num_cnn=num_cnn,
            channel=channel,
            block_num=i,
            is_50=is_50
        )

    output = keras.layers.GlobalAveragePooling2D(name="avg_pool")(output)
    output = keras.layers.Flatten(name='flatten')(output)
    output = keras.layers.Dense(1000, activation='relu', name='fc2')(output)
    output = keras.layers.Dense(1, activation='sigmoid', name='predictions')(output)



    model = keras.Model(
        inputs=input_layer,
        outputs=output
    )
    return model

# %%
resnet_34 = build_resnet(input_shape=(224, 224, 3), is_50=False)
resnet_34.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)         9472      ['input_2[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 54, 54, 64)           0         ['conv2d_1[0][0]']
#  D)
#
#  block0_conv0_1 (Conv2D)     (None, 54, 54, 64)           36928     ['max_pooling2d[0][0]']
#
#  batch_normalization_6 (Bat  (None, 54, 54, 64)           256       ['block0_conv0_1[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 54, 54, 64)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  block0_conv0_2 (Conv2D)     (None, 54, 54, 64)           36928     ['activation_3[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 54, 54, 64)           4160      ['max_pooling2d[0][0]']
#
#  batch_normalization_7 (Bat  (None, 54, 54, 64)           256       ['block0_conv0_2[0][0]']
#  chNormalization)
#
#  block0_add_0 (Add)          (None, 54, 54, 64)           0         ['conv2d_2[0][0]',
#                                                                      'batch_normalization_7[0][0]'
#                                                                     ]
#
#  block0_out_0 (Activation)   (None, 54, 54, 64)           0         ['block0_add_0[0][0]']
#
#  block0_conv1_1 (Conv2D)     (None, 54, 54, 64)           36928     ['block0_out_0[0][0]']
#
#  batch_normalization_8 (Bat  (None, 54, 54, 64)           256       ['block0_conv1_1[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 54, 54, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  block0_conv1_2 (Conv2D)     (None, 54, 54, 64)           36928     ['activation_4[0][0]']
#
#  batch_normalization_9 (Bat  (None, 54, 54, 64)           256       ['block0_conv1_2[0][0]']
#  chNormalization)
#
#  block0_add_1 (Add)          (None, 54, 54, 64)           0         ['conv2d_2[0][0]',
#                                                                      'batch_normalization_9[0][0]'
#                                                                     ]
#
#  block0_out_1 (Activation)   (None, 54, 54, 64)           0         ['block0_add_1[0][0]']
#
#  block0_conv2_1 (Conv2D)     (None, 54, 54, 64)           36928     ['block0_out_1[0][0]']
#
#  batch_normalization_10 (Ba  (None, 54, 54, 64)           256       ['block0_conv2_1[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 54, 54, 64)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  block0_conv2_2 (Conv2D)     (None, 54, 54, 64)           36928     ['activation_5[0][0]']
#
#  batch_normalization_11 (Ba  (None, 54, 54, 64)           256       ['block0_conv2_2[0][0]']
#  tchNormalization)
#
#  block0_add_2 (Add)          (None, 54, 54, 64)           0         ['conv2d_2[0][0]',
#                                                                      'batch_normalization_11[0][0]
#                                                                     ']
#
#  block0_out_2 (Activation)   (None, 54, 54, 64)           0         ['block0_add_2[0][0]']
#
#  block1_conv0_1 (Conv2D)     (None, 54, 54, 128)          73856     ['block0_out_2[0][0]']
#
#  batch_normalization_12 (Ba  (None, 54, 54, 128)          512       ['block1_conv0_1[0][0]']
#  tchNormalization)
#
#  activation_6 (Activation)   (None, 54, 54, 128)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  block1_conv0_2 (Conv2D)     (None, 54, 54, 128)          147584    ['activation_6[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 54, 54, 128)          8320      ['block0_out_2[0][0]']
#
#  batch_normalization_13 (Ba  (None, 54, 54, 128)          512       ['block1_conv0_2[0][0]']
#  tchNormalization)
#
#  block1_add_0 (Add)          (None, 54, 54, 128)          0         ['conv2d_3[0][0]',
#                                                                      'batch_normalization_13[0][0]
#                                                                     ']
#
#  block1_out_0 (Activation)   (None, 54, 54, 128)          0         ['block1_add_0[0][0]']
#
#  block1_conv1_1 (Conv2D)     (None, 54, 54, 128)          147584    ['block1_out_0[0][0]']
#
#  batch_normalization_14 (Ba  (None, 54, 54, 128)          512       ['block1_conv1_1[0][0]']
#  tchNormalization)
#
#  activation_7 (Activation)   (None, 54, 54, 128)          0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  block1_conv1_2 (Conv2D)     (None, 54, 54, 128)          147584    ['activation_7[0][0]']
#
#  batch_normalization_15 (Ba  (None, 54, 54, 128)          512       ['block1_conv1_2[0][0]']
#  tchNormalization)
#
#  block1_add_1 (Add)          (None, 54, 54, 128)          0         ['conv2d_3[0][0]',
#                                                                      'batch_normalization_15[0][0]
#                                                                     ']
#
#  block1_out_1 (Activation)   (None, 54, 54, 128)          0         ['block1_add_1[0][0]']
#
#  block1_conv2_1 (Conv2D)     (None, 54, 54, 128)          147584    ['block1_out_1[0][0]']
#
#  batch_normalization_16 (Ba  (None, 54, 54, 128)          512       ['block1_conv2_1[0][0]']
#  tchNormalization)
#
#  activation_8 (Activation)   (None, 54, 54, 128)          0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  block1_conv2_2 (Conv2D)     (None, 54, 54, 128)          147584    ['activation_8[0][0]']
#
#  batch_normalization_17 (Ba  (None, 54, 54, 128)          512       ['block1_conv2_2[0][0]']
#  tchNormalization)
#
#  block1_add_2 (Add)          (None, 54, 54, 128)          0         ['conv2d_3[0][0]',
#                                                                      'batch_normalization_17[0][0]
#                                                                     ']
#
#  block1_out_2 (Activation)   (None, 54, 54, 128)          0         ['block1_add_2[0][0]']
#
#  block1_conv3_1 (Conv2D)     (None, 54, 54, 128)          147584    ['block1_out_2[0][0]']
#
#  batch_normalization_18 (Ba  (None, 54, 54, 128)          512       ['block1_conv3_1[0][0]']
#  tchNormalization)
#
#  activation_9 (Activation)   (None, 54, 54, 128)          0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  block1_conv3_2 (Conv2D)     (None, 54, 54, 128)          147584    ['activation_9[0][0]']
#
#  batch_normalization_19 (Ba  (None, 54, 54, 128)          512       ['block1_conv3_2[0][0]']
#  tchNormalization)
#
#  block1_add_3 (Add)          (None, 54, 54, 128)          0         ['conv2d_3[0][0]',
#                                                                      'batch_normalization_19[0][0]
#                                                                     ']
#
#  block1_out_3 (Activation)   (None, 54, 54, 128)          0         ['block1_add_3[0][0]']
#
#  block2_conv0_1 (Conv2D)     (None, 54, 54, 256)          295168    ['block1_out_3[0][0]']
#
#  batch_normalization_20 (Ba  (None, 54, 54, 256)          1024      ['block2_conv0_1[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 54, 54, 256)          0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  block2_conv0_2 (Conv2D)     (None, 54, 54, 256)          590080    ['activation_10[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 54, 54, 256)          33024     ['block1_out_3[0][0]']
#
#  batch_normalization_21 (Ba  (None, 54, 54, 256)          1024      ['block2_conv0_2[0][0]']
#  tchNormalization)
#
#  block2_add_0 (Add)          (None, 54, 54, 256)          0         ['conv2d_4[0][0]',
#                                                                      'batch_normalization_21[0][0]
#                                                                     ']
#
#  block2_out_0 (Activation)   (None, 54, 54, 256)          0         ['block2_add_0[0][0]']
#
#  block2_conv1_1 (Conv2D)     (None, 54, 54, 256)          590080    ['block2_out_0[0][0]']
#
#  batch_normalization_22 (Ba  (None, 54, 54, 256)          1024      ['block2_conv1_1[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 54, 54, 256)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  block2_conv1_2 (Conv2D)     (None, 54, 54, 256)          590080    ['activation_11[0][0]']
#
#  batch_normalization_23 (Ba  (None, 54, 54, 256)          1024      ['block2_conv1_2[0][0]']
#  tchNormalization)
#
#  block2_add_1 (Add)          (None, 54, 54, 256)          0         ['conv2d_4[0][0]',
#                                                                      'batch_normalization_23[0][0]
#                                                                     ']
#
#  block2_out_1 (Activation)   (None, 54, 54, 256)          0         ['block2_add_1[0][0]']
#
#  block2_conv2_1 (Conv2D)     (None, 54, 54, 256)          590080    ['block2_out_1[0][0]']
#
#  batch_normalization_24 (Ba  (None, 54, 54, 256)          1024      ['block2_conv2_1[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 54, 54, 256)          0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  block2_conv2_2 (Conv2D)     (None, 54, 54, 256)          590080    ['activation_12[0][0]']
#
#  batch_normalization_25 (Ba  (None, 54, 54, 256)          1024      ['block2_conv2_2[0][0]']
#  tchNormalization)
#
#  block2_add_2 (Add)          (None, 54, 54, 256)          0         ['conv2d_4[0][0]',
#                                                                      'batch_normalization_25[0][0]
#                                                                     ']
#
#  block2_out_2 (Activation)   (None, 54, 54, 256)          0         ['block2_add_2[0][0]']
#
#  block2_conv3_1 (Conv2D)     (None, 54, 54, 256)          590080    ['block2_out_2[0][0]']
#
#  batch_normalization_26 (Ba  (None, 54, 54, 256)          1024      ['block2_conv3_1[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 54, 54, 256)          0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  block2_conv3_2 (Conv2D)     (None, 54, 54, 256)          590080    ['activation_13[0][0]']
#
#  batch_normalization_27 (Ba  (None, 54, 54, 256)          1024      ['block2_conv3_2[0][0]']
#  tchNormalization)
#
#  block2_add_3 (Add)          (None, 54, 54, 256)          0         ['conv2d_4[0][0]',
#                                                                      'batch_normalization_27[0][0]
#                                                                     ']
#
#  block2_out_3 (Activation)   (None, 54, 54, 256)          0         ['block2_add_3[0][0]']
#
#  block2_conv4_1 (Conv2D)     (None, 54, 54, 256)          590080    ['block2_out_3[0][0]']
#
#  batch_normalization_28 (Ba  (None, 54, 54, 256)          1024      ['block2_conv4_1[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 54, 54, 256)          0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  block2_conv4_2 (Conv2D)     (None, 54, 54, 256)          590080    ['activation_14[0][0]']
#
#  batch_normalization_29 (Ba  (None, 54, 54, 256)          1024      ['block2_conv4_2[0][0]']
#  tchNormalization)
#
#  block2_add_4 (Add)          (None, 54, 54, 256)          0         ['conv2d_4[0][0]',
#                                                                      'batch_normalization_29[0][0]
#                                                                     ']
#
#  block2_out_4 (Activation)   (None, 54, 54, 256)          0         ['block2_add_4[0][0]']
#
#  block2_conv5_1 (Conv2D)     (None, 54, 54, 256)          590080    ['block2_out_4[0][0]']
#
#  batch_normalization_30 (Ba  (None, 54, 54, 256)          1024      ['block2_conv5_1[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 54, 54, 256)          0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  block2_conv5_2 (Conv2D)     (None, 54, 54, 256)          590080    ['activation_15[0][0]']
#
#  batch_normalization_31 (Ba  (None, 54, 54, 256)          1024      ['block2_conv5_2[0][0]']
#  tchNormalization)
#
#  block2_add_5 (Add)          (None, 54, 54, 256)          0         ['conv2d_4[0][0]',
#                                                                      'batch_normalization_31[0][0]
#                                                                     ']
#
#  block2_out_5 (Activation)   (None, 54, 54, 256)          0         ['block2_add_5[0][0]']
#
#  block3_conv0_1 (Conv2D)     (None, 54, 54, 512)          1180160   ['block2_out_5[0][0]']
#
#  batch_normalization_32 (Ba  (None, 54, 54, 512)          2048      ['block3_conv0_1[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 54, 54, 512)          0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  block3_conv0_2 (Conv2D)     (None, 54, 54, 512)          2359808   ['activation_16[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 54, 54, 512)          131584    ['block2_out_5[0][0]']
#
#  batch_normalization_33 (Ba  (None, 54, 54, 512)          2048      ['block3_conv0_2[0][0]']
#  tchNormalization)
#
#  block3_add_0 (Add)          (None, 54, 54, 512)          0         ['conv2d_5[0][0]',
#                                                                      'batch_normalization_33[0][0]
#                                                                     ']
#
#  block3_out_0 (Activation)   (None, 54, 54, 512)          0         ['block3_add_0[0][0]']
#
#  block3_conv1_1 (Conv2D)     (None, 54, 54, 512)          2359808   ['block3_out_0[0][0]']
#
#  batch_normalization_34 (Ba  (None, 54, 54, 512)          2048      ['block3_conv1_1[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 54, 54, 512)          0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  block3_conv1_2 (Conv2D)     (None, 54, 54, 512)          2359808   ['activation_17[0][0]']
#
#  batch_normalization_35 (Ba  (None, 54, 54, 512)          2048      ['block3_conv1_2[0][0]']
#  tchNormalization)
#
#  block3_add_1 (Add)          (None, 54, 54, 512)          0         ['conv2d_5[0][0]',
#                                                                      'batch_normalization_35[0][0]
#                                                                     ']
#
#  block3_out_1 (Activation)   (None, 54, 54, 512)          0         ['block3_add_1[0][0]']
#
#  block3_conv2_1 (Conv2D)     (None, 54, 54, 512)          2359808   ['block3_out_1[0][0]']
#
#  batch_normalization_36 (Ba  (None, 54, 54, 512)          2048      ['block3_conv2_1[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 54, 54, 512)          0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  block3_conv2_2 (Conv2D)     (None, 54, 54, 512)          2359808   ['activation_18[0][0]']
#
#  batch_normalization_37 (Ba  (None, 54, 54, 512)          2048      ['block3_conv2_2[0][0]']
#  tchNormalization)
#
#  block3_add_2 (Add)          (None, 54, 54, 512)          0         ['conv2d_5[0][0]',
#                                                                      'batch_normalization_37[0][0]
#                                                                     ']
#
#  block3_out_2 (Activation)   (None, 54, 54, 512)          0         ['block3_add_2[0][0]']
#
#  avg_pool (GlobalAveragePoo  (None, 512)                  0         ['block3_out_2[0][0]']
#  ling2D)
#
#  flatten (Flatten)           (None, 512)                  0         ['avg_pool[0][0]']
#
#  fc2 (Dense)                 (None, 1000)                 513000    ['flatten[0][0]']
#
#  predictions (Dense)         (None, 1)                    1001      ['fc2[0][0]']
#
# ==================================================================================================
# Total params: 21824529 (83.25 MB)
# Trainable params: 21809425 (83.20 MB)
# Non-trainable params: 15104 (59.00 KB)
# __________________________________________________________________________________________________

# %%
resnet_50 = build_resnet(input_shape=(224, 224, 3), is_50=True)
resnet_50.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_6 (Conv2D)           (None, 109, 109, 64)         9472      ['input_3[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 54, 54, 64)           0         ['conv2d_6[0][0]']
#  g2D)
#
#  block0_conv0_1x1 (Conv2D)   (None, 54, 54, 64)           4160      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_38 (Ba  (None, 54, 54, 64)           256       ['block0_conv0_1x1[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 54, 54, 64)           0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  block0_conv0_3x3 (Conv2D)   (None, 54, 54, 64)           36928     ['activation_19[0][0]']
#
#  batch_normalization_39 (Ba  (None, 54, 54, 64)           256       ['block0_conv0_3x3[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 54, 54, 64)           0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  block0_conv0_1x1_2 (Conv2D  (None, 54, 54, 256)          16640     ['activation_20[0][0]']
#  )
#
#  conv2d_7 (Conv2D)           (None, 54, 54, 256)          16640     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_40 (Ba  (None, 54, 54, 256)          1024      ['block0_conv0_1x1_2[0][0]']
#  tchNormalization)
#
#  block0_add_0 (Add)          (None, 54, 54, 256)          0         ['conv2d_7[0][0]',
#                                                                      'batch_normalization_40[0][0]
#                                                                     ']
#
#  block0_out_0 (Activation)   (None, 54, 54, 256)          0         ['block0_add_0[0][0]']
#
#  block0_conv1_1x1 (Conv2D)   (None, 54, 54, 64)           16448     ['block0_out_0[0][0]']
#
#  batch_normalization_41 (Ba  (None, 54, 54, 64)           256       ['block0_conv1_1x1[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 54, 54, 64)           0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  block0_conv1_3x3 (Conv2D)   (None, 54, 54, 64)           36928     ['activation_21[0][0]']
#
#  batch_normalization_42 (Ba  (None, 54, 54, 64)           256       ['block0_conv1_3x3[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 54, 54, 64)           0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  block0_conv1_1x1_2 (Conv2D  (None, 54, 54, 256)          16640     ['activation_22[0][0]']
#  )
#
#  batch_normalization_43 (Ba  (None, 54, 54, 256)          1024      ['block0_conv1_1x1_2[0][0]']
#  tchNormalization)
#
#  block0_add_1 (Add)          (None, 54, 54, 256)          0         ['conv2d_7[0][0]',
#                                                                      'batch_normalization_43[0][0]
#                                                                     ']
#
#  block0_out_1 (Activation)   (None, 54, 54, 256)          0         ['block0_add_1[0][0]']
#
#  block0_conv2_1x1 (Conv2D)   (None, 54, 54, 64)           16448     ['block0_out_1[0][0]']
#
#  batch_normalization_44 (Ba  (None, 54, 54, 64)           256       ['block0_conv2_1x1[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 54, 54, 64)           0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  block0_conv2_3x3 (Conv2D)   (None, 54, 54, 64)           36928     ['activation_23[0][0]']
#
#  batch_normalization_45 (Ba  (None, 54, 54, 64)           256       ['block0_conv2_3x3[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 54, 54, 64)           0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  block0_conv2_1x1_2 (Conv2D  (None, 54, 54, 256)          16640     ['activation_24[0][0]']
#  )
#
#  batch_normalization_46 (Ba  (None, 54, 54, 256)          1024      ['block0_conv2_1x1_2[0][0]']
#  tchNormalization)
#
#  block0_add_2 (Add)          (None, 54, 54, 256)          0         ['conv2d_7[0][0]',
#                                                                      'batch_normalization_46[0][0]
#                                                                     ']
#
#  block0_out_2 (Activation)   (None, 54, 54, 256)          0         ['block0_add_2[0][0]']
#
#  block1_conv0_1x1 (Conv2D)   (None, 54, 54, 128)          32896     ['block0_out_2[0][0]']
#
#  batch_normalization_47 (Ba  (None, 54, 54, 128)          512       ['block1_conv0_1x1[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 54, 54, 128)          0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  block1_conv0_3x3 (Conv2D)   (None, 54, 54, 128)          147584    ['activation_25[0][0]']
#
#  batch_normalization_48 (Ba  (None, 54, 54, 128)          512       ['block1_conv0_3x3[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 54, 54, 128)          0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  block1_conv0_1x1_2 (Conv2D  (None, 54, 54, 512)          66048     ['activation_26[0][0]']
#  )
#
#  conv2d_8 (Conv2D)           (None, 54, 54, 512)          131584    ['block0_out_2[0][0]']
#
#  batch_normalization_49 (Ba  (None, 54, 54, 512)          2048      ['block1_conv0_1x1_2[0][0]']
#  tchNormalization)
#
#  block1_add_0 (Add)          (None, 54, 54, 512)          0         ['conv2d_8[0][0]',
#                                                                      'batch_normalization_49[0][0]
#                                                                     ']
#
#  block1_out_0 (Activation)   (None, 54, 54, 512)          0         ['block1_add_0[0][0]']
#
#  block1_conv1_1x1 (Conv2D)   (None, 54, 54, 128)          65664     ['block1_out_0[0][0]']
#
#  batch_normalization_50 (Ba  (None, 54, 54, 128)          512       ['block1_conv1_1x1[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 54, 54, 128)          0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  block1_conv1_3x3 (Conv2D)   (None, 54, 54, 128)          147584    ['activation_27[0][0]']
#
#  batch_normalization_51 (Ba  (None, 54, 54, 128)          512       ['block1_conv1_3x3[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 54, 54, 128)          0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  block1_conv1_1x1_2 (Conv2D  (None, 54, 54, 512)          66048     ['activation_28[0][0]']
#  )
#
#  batch_normalization_52 (Ba  (None, 54, 54, 512)          2048      ['block1_conv1_1x1_2[0][0]']
#  tchNormalization)
#
#  block1_add_1 (Add)          (None, 54, 54, 512)          0         ['conv2d_8[0][0]',
#                                                                      'batch_normalization_52[0][0]
#                                                                     ']
#
#  block1_out_1 (Activation)   (None, 54, 54, 512)          0         ['block1_add_1[0][0]']
#
#  block1_conv2_1x1 (Conv2D)   (None, 54, 54, 128)          65664     ['block1_out_1[0][0]']
#
#  batch_normalization_53 (Ba  (None, 54, 54, 128)          512       ['block1_conv2_1x1[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 54, 54, 128)          0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  block1_conv2_3x3 (Conv2D)   (None, 54, 54, 128)          147584    ['activation_29[0][0]']
#
#  batch_normalization_54 (Ba  (None, 54, 54, 128)          512       ['block1_conv2_3x3[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 54, 54, 128)          0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  block1_conv2_1x1_2 (Conv2D  (None, 54, 54, 512)          66048     ['activation_30[0][0]']
#  )
#
#  batch_normalization_55 (Ba  (None, 54, 54, 512)          2048      ['block1_conv2_1x1_2[0][0]']
#  tchNormalization)
#
#  block1_add_2 (Add)          (None, 54, 54, 512)          0         ['conv2d_8[0][0]',
#                                                                      'batch_normalization_55[0][0]
#                                                                     ']
#
#  block1_out_2 (Activation)   (None, 54, 54, 512)          0         ['block1_add_2[0][0]']
#
#  block1_conv3_1x1 (Conv2D)   (None, 54, 54, 128)          65664     ['block1_out_2[0][0]']
#
#  batch_normalization_56 (Ba  (None, 54, 54, 128)          512       ['block1_conv3_1x1[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 54, 54, 128)          0         ['batch_normalization_56[0][0]
#                                                                     ']
#
#  block1_conv3_3x3 (Conv2D)   (None, 54, 54, 128)          147584    ['activation_31[0][0]']
#
#  batch_normalization_57 (Ba  (None, 54, 54, 128)          512       ['block1_conv3_3x3[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 54, 54, 128)          0         ['batch_normalization_57[0][0]
#                                                                     ']
#
#  block1_conv3_1x1_2 (Conv2D  (None, 54, 54, 512)          66048     ['activation_32[0][0]']
#  )
#
#  batch_normalization_58 (Ba  (None, 54, 54, 512)          2048      ['block1_conv3_1x1_2[0][0]']
#  tchNormalization)
#
#  block1_add_3 (Add)          (None, 54, 54, 512)          0         ['conv2d_8[0][0]',
#                                                                      'batch_normalization_58[0][0]
#                                                                     ']
#
#  block1_out_3 (Activation)   (None, 54, 54, 512)          0         ['block1_add_3[0][0]']
#
#  block2_conv0_1x1 (Conv2D)   (None, 54, 54, 256)          131328    ['block1_out_3[0][0]']
#
#  batch_normalization_59 (Ba  (None, 54, 54, 256)          1024      ['block2_conv0_1x1[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 54, 54, 256)          0         ['batch_normalization_59[0][0]
#                                                                     ']
#
#  block2_conv0_3x3 (Conv2D)   (None, 54, 54, 256)          590080    ['activation_33[0][0]']
#
#  batch_normalization_60 (Ba  (None, 54, 54, 256)          1024      ['block2_conv0_3x3[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 54, 54, 256)          0         ['batch_normalization_60[0][0]
#                                                                     ']
#
#  block2_conv0_1x1_2 (Conv2D  (None, 54, 54, 1024)         263168    ['activation_34[0][0]']
#  )
#
#  conv2d_9 (Conv2D)           (None, 54, 54, 1024)         525312    ['block1_out_3[0][0]']
#
#  batch_normalization_61 (Ba  (None, 54, 54, 1024)         4096      ['block2_conv0_1x1_2[0][0]']
#  tchNormalization)
#
#  block2_add_0 (Add)          (None, 54, 54, 1024)         0         ['conv2d_9[0][0]',
#                                                                      'batch_normalization_61[0][0]
#                                                                     ']
#
#  block2_out_0 (Activation)   (None, 54, 54, 1024)         0         ['block2_add_0[0][0]']
#
#  block2_conv1_1x1 (Conv2D)   (None, 54, 54, 256)          262400    ['block2_out_0[0][0]']
#
#  batch_normalization_62 (Ba  (None, 54, 54, 256)          1024      ['block2_conv1_1x1[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 54, 54, 256)          0         ['batch_normalization_62[0][0]
#                                                                     ']
#
#  block2_conv1_3x3 (Conv2D)   (None, 54, 54, 256)          590080    ['activation_35[0][0]']
#
#  batch_normalization_63 (Ba  (None, 54, 54, 256)          1024      ['block2_conv1_3x3[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 54, 54, 256)          0         ['batch_normalization_63[0][0]
#                                                                     ']
#
#  block2_conv1_1x1_2 (Conv2D  (None, 54, 54, 1024)         263168    ['activation_36[0][0]']
#  )
#
#  batch_normalization_64 (Ba  (None, 54, 54, 1024)         4096      ['block2_conv1_1x1_2[0][0]']
#  tchNormalization)
#
#  block2_add_1 (Add)          (None, 54, 54, 1024)         0         ['conv2d_9[0][0]',
#                                                                      'batch_normalization_64[0][0]
#                                                                     ']
#
#  block2_out_1 (Activation)   (None, 54, 54, 1024)         0         ['block2_add_1[0][0]']
#
#  block2_conv2_1x1 (Conv2D)   (None, 54, 54, 256)          262400    ['block2_out_1[0][0]']
#
#  batch_normalization_65 (Ba  (None, 54, 54, 256)          1024      ['block2_conv2_1x1[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 54, 54, 256)          0         ['batch_normalization_65[0][0]
#                                                                     ']
#
#  block2_conv2_3x3 (Conv2D)   (None, 54, 54, 256)          590080    ['activation_37[0][0]']
#
#  batch_normalization_66 (Ba  (None, 54, 54, 256)          1024      ['block2_conv2_3x3[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 54, 54, 256)          0         ['batch_normalization_66[0][0]
#                                                                     ']
#
#  block2_conv2_1x1_2 (Conv2D  (None, 54, 54, 1024)         263168    ['activation_38[0][0]']
#  )
#
#  batch_normalization_67 (Ba  (None, 54, 54, 1024)         4096      ['block2_conv2_1x1_2[0][0]']
#  tchNormalization)
#
#  block2_add_2 (Add)          (None, 54, 54, 1024)         0         ['conv2d_9[0][0]',
#                                                                      'batch_normalization_67[0][0]
#                                                                     ']
#
#  block2_out_2 (Activation)   (None, 54, 54, 1024)         0         ['block2_add_2[0][0]']
#
#  block2_conv3_1x1 (Conv2D)   (None, 54, 54, 256)          262400    ['block2_out_2[0][0]']
#
#  batch_normalization_68 (Ba  (None, 54, 54, 256)          1024      ['block2_conv3_1x1[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 54, 54, 256)          0         ['batch_normalization_68[0][0]
#                                                                     ']
#
#  block2_conv3_3x3 (Conv2D)   (None, 54, 54, 256)          590080    ['activation_39[0][0]']
#
#  batch_normalization_69 (Ba  (None, 54, 54, 256)          1024      ['block2_conv3_3x3[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 54, 54, 256)          0         ['batch_normalization_69[0][0]
#                                                                     ']
#
#  block2_conv3_1x1_2 (Conv2D  (None, 54, 54, 1024)         263168    ['activation_40[0][0]']
#  )
#
#  batch_normalization_70 (Ba  (None, 54, 54, 1024)         4096      ['block2_conv3_1x1_2[0][0]']
#  tchNormalization)
#
#  block2_add_3 (Add)          (None, 54, 54, 1024)         0         ['conv2d_9[0][0]',
#                                                                      'batch_normalization_70[0][0]
#                                                                     ']
#
#  block2_out_3 (Activation)   (None, 54, 54, 1024)         0         ['block2_add_3[0][0]']
#
#  block2_conv4_1x1 (Conv2D)   (None, 54, 54, 256)          262400    ['block2_out_3[0][0]']
#
#  batch_normalization_71 (Ba  (None, 54, 54, 256)          1024      ['block2_conv4_1x1[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 54, 54, 256)          0         ['batch_normalization_71[0][0]
#                                                                     ']
#
#  block2_conv4_3x3 (Conv2D)   (None, 54, 54, 256)          590080    ['activation_41[0][0]']
#
#  batch_normalization_72 (Ba  (None, 54, 54, 256)          1024      ['block2_conv4_3x3[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 54, 54, 256)          0         ['batch_normalization_72[0][0]
#                                                                     ']
#
#  block2_conv4_1x1_2 (Conv2D  (None, 54, 54, 1024)         263168    ['activation_42[0][0]']
#  )
#
#  batch_normalization_73 (Ba  (None, 54, 54, 1024)         4096      ['block2_conv4_1x1_2[0][0]']
#  tchNormalization)
#
#  block2_add_4 (Add)          (None, 54, 54, 1024)         0         ['conv2d_9[0][0]',
#                                                                      'batch_normalization_73[0][0]
#                                                                     ']
#
#  block2_out_4 (Activation)   (None, 54, 54, 1024)         0         ['block2_add_4[0][0]']
#
#  block2_conv5_1x1 (Conv2D)   (None, 54, 54, 256)          262400    ['block2_out_4[0][0]']
#
#  batch_normalization_74 (Ba  (None, 54, 54, 256)          1024      ['block2_conv5_1x1[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 54, 54, 256)          0         ['batch_normalization_74[0][0]
#                                                                     ']
#
#  block2_conv5_3x3 (Conv2D)   (None, 54, 54, 256)          590080    ['activation_43[0][0]']
#
#  batch_normalization_75 (Ba  (None, 54, 54, 256)          1024      ['block2_conv5_3x3[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 54, 54, 256)          0         ['batch_normalization_75[0][0]
#                                                                     ']
#
#  block2_conv5_1x1_2 (Conv2D  (None, 54, 54, 1024)         263168    ['activation_44[0][0]']
#  )
#
#  batch_normalization_76 (Ba  (None, 54, 54, 1024)         4096      ['block2_conv5_1x1_2[0][0]']
#  tchNormalization)
#
#  block2_add_5 (Add)          (None, 54, 54, 1024)         0         ['conv2d_9[0][0]',
#                                                                      'batch_normalization_76[0][0]
#                                                                     ']
#
#  block2_out_5 (Activation)   (None, 54, 54, 1024)         0         ['block2_add_5[0][0]']
#
#  block3_conv0_1x1 (Conv2D)   (None, 54, 54, 512)          524800    ['block2_out_5[0][0]']
#
#  batch_normalization_77 (Ba  (None, 54, 54, 512)          2048      ['block3_conv0_1x1[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 54, 54, 512)          0         ['batch_normalization_77[0][0]
#                                                                     ']
#
#  block3_conv0_3x3 (Conv2D)   (None, 54, 54, 512)          2359808   ['activation_45[0][0]']
#
#  batch_normalization_78 (Ba  (None, 54, 54, 512)          2048      ['block3_conv0_3x3[0][0]']
#  tchNormalization)
#
#  activation_46 (Activation)  (None, 54, 54, 512)          0         ['batch_normalization_78[0][0]
#                                                                     ']
#
#  block3_conv0_1x1_2 (Conv2D  (None, 54, 54, 2048)         1050624   ['activation_46[0][0]']
#  )
#
#  conv2d_10 (Conv2D)          (None, 54, 54, 2048)         2099200   ['block2_out_5[0][0]']
#
#  batch_normalization_79 (Ba  (None, 54, 54, 2048)         8192      ['block3_conv0_1x1_2[0][0]']
#  tchNormalization)
#
#  block3_add_0 (Add)          (None, 54, 54, 2048)         0         ['conv2d_10[0][0]',
#                                                                      'batch_normalization_79[0][0]
#                                                                     ']
#
#  block3_out_0 (Activation)   (None, 54, 54, 2048)         0         ['block3_add_0[0][0]']
#
#  block3_conv1_1x1 (Conv2D)   (None, 54, 54, 512)          1049088   ['block3_out_0[0][0]']
#
#  batch_normalization_80 (Ba  (None, 54, 54, 512)          2048      ['block3_conv1_1x1[0][0]']
#  tchNormalization)
#
#  activation_47 (Activation)  (None, 54, 54, 512)          0         ['batch_normalization_80[0][0]
#                                                                     ']
#
#  block3_conv1_3x3 (Conv2D)   (None, 54, 54, 512)          2359808   ['activation_47[0][0]']
#
#  batch_normalization_81 (Ba  (None, 54, 54, 512)          2048      ['block3_conv1_3x3[0][0]']
#  tchNormalization)
#
#  activation_48 (Activation)  (None, 54, 54, 512)          0         ['batch_normalization_81[0][0]
#                                                                     ']
#
#  block3_conv1_1x1_2 (Conv2D  (None, 54, 54, 2048)         1050624   ['activation_48[0][0]']
#  )
#
#  batch_normalization_82 (Ba  (None, 54, 54, 2048)         8192      ['block3_conv1_1x1_2[0][0]']
#  tchNormalization)
#
#  block3_add_1 (Add)          (None, 54, 54, 2048)         0         ['conv2d_10[0][0]',
#                                                                      'batch_normalization_82[0][0]
#                                                                     ']
#
#  block3_out_1 (Activation)   (None, 54, 54, 2048)         0         ['block3_add_1[0][0]']
#
#  block3_conv2_1x1 (Conv2D)   (None, 54, 54, 512)          1049088   ['block3_out_1[0][0]']
#
#  batch_normalization_83 (Ba  (None, 54, 54, 512)          2048      ['block3_conv2_1x1[0][0]']
#  tchNormalization)
#
#  activation_49 (Activation)  (None, 54, 54, 512)          0         ['batch_normalization_83[0][0]
#                                                                     ']
#
#  block3_conv2_3x3 (Conv2D)   (None, 54, 54, 512)          2359808   ['activation_49[0][0]']
#
#  batch_normalization_84 (Ba  (None, 54, 54, 512)          2048      ['block3_conv2_3x3[0][0]']
#  tchNormalization)
#
#  activation_50 (Activation)  (None, 54, 54, 512)          0         ['batch_normalization_84[0][0]
#                                                                     ']
#
#  block3_conv2_1x1_2 (Conv2D  (None, 54, 54, 2048)         1050624   ['activation_50[0][0]']
#  )
#
#  batch_normalization_85 (Ba  (None, 54, 54, 2048)         8192      ['block3_conv2_1x1_2[0][0]']
#  tchNormalization)
#
#  block3_add_2 (Add)          (None, 54, 54, 2048)         0         ['conv2d_10[0][0]',
#                                                                      'batch_normalization_85[0][0]
#                                                                     ']
#
#  block3_out_2 (Activation)   (None, 54, 54, 2048)         0         ['block3_add_2[0][0]']
#
#  avg_pool (GlobalAveragePoo  (None, 2048)                 0         ['block3_out_2[0][0]']
#  ling2D)
#
#  flatten (Flatten)           (None, 2048)                 0         ['avg_pool[0][0]']
#
#  fc2 (Dense)                 (None, 1000)                 2049000   ['flatten[0][0]']
#
#  predictions (Dense)         (None, 1)                    1001      ['fc2[0][0]']
#
# ==================================================================================================
# Total params: 25622097 (97.74 MB)
# Trainable params: 25576785 (97.57 MB)
# Non-trainable params: 45312 (177.00 KB)
# __________________________________________________________________________________________________

# %%
BATCH_SIZE = 16
EPOCH = 10

# %%
ds_train = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE)
ds_test = apply_normalize_on_dataset(ds_test, batch_size=BATCH_SIZE)

# %%
ds_train
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %% [markdown]
# ## 3. Model fitting

# %%
callbacks_list = [
    keras.callbacks.EarlyStopping(monitor="val_accuracy", # 모델의 검증 정확도를 모니터링
                                  patience=2, # 두 번의 epoch동안 지표가 향상되지 않으면 훈련 중지
    )]

# %%
resnet_34.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_34 = resnet_34.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    callbacks=callbacks_list,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/10
# 1163/1163 [==============================] - 999s 828ms/step - loss: 0.6364 - accuracy: 0.6270 - val_loss: 1.4123 - val_accuracy: 0.5306
# Epoch 2/10
#  692/1163 [================>.............] - ETA: 5:58 - loss: 0.5638 - accuracy: 0.7072
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-26e07847f726> in <cell line: 7>()
#       5 )
#       6
# ----> 7 history_34 = resnet_34.fit(
#       8     ds_train,
#       9     steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1781                         ):
#    1782                             callbacks.on_train_batch_begin(step)
# -> 1783                             tmp_logs = self.train_function(iterator)
#    1784                             if data_handler.should_sync:
#    1785                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     829
#     830       with OptionalXlaContext(self._jit_compile):
# --> 831         result = self._call(*args, **kwds)
#     832
#     833       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     865       # In this case we have created variables on the first call, so we run the
#     866       # defunned version which is guaranteed to never create variables.
# --> 867       return tracing_compilation.call_function(
#     868           args, kwds, self._no_variable_creation_config
#     869       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1262         and executing_eagerly):
#    1263       # No tape is watching; skip to running the function.
# -> 1264       return self._inference_function.flat_call(args)
#    1265     forward_backward = self._select_forward_and_backward_functions(
#    1266         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in flat_call(self, args)
#     215   def flat_call(self, args: Sequence[core.Tensor]) -> Any:
#     216     """Calls with tensor inputs and returns the structured output."""
# --> 217     flat_outputs = self(*args)
#     218     return self.function_type.pack_output(flat_outputs)
#     219
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in __call__(self, *args)
#     250         with record.stop_recording():
#     251           if self._bound_context.executing_eagerly():
# --> 252             outputs = self._bound_context.call_function(
#     253                 self.name,
#     254                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1477     cancellation_context = cancellation.context()
#    1478     if cancellation_context is None:
# -> 1479       outputs = execute.execute(
#    1480           name.decode("utf-8"),
#    1481           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58         for t in inputs
#      59     ]
# ---> 60     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      61                                         inputs, attrs, num_outputs)
#      62   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
resnet_50.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_50 = resnet_50.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    callbacks=callbacks_list,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)

# %% [markdown]
# ## 4. Results

# %%
import matplotlib.pyplot as plt

plt.plot(history_34.history['loss'], 'r')
plt.plot(history_50.history['loss'], 'b')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['resnet34', 'restnet50'], loc='upper left')
plt.show()

# %%
plt.plot(history_34.history['val_accuracy'], 'r')
plt.plot(history_50.history['val_accuracy'], 'b')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['resnet34', 'restnet50'], loc='upper left')
plt.show()

# %% [markdown]
# ## 5. Ablation Study (Model with skip connection vs. without skip connection)

# %% [markdown]
# # 회고
# - `tensorflow_datasets`의 버전이 4.4.0인 경우 손상된 이미지가 있는걸로 추정. 이 경우 이를 4.9.3으로 업그레이드하거나 최선 버전이 있는 COLAB에서 진행하면 해결가능했다.
# - 이미지 dataset의 size 맞추는 작업의 어려움을 느꼈다. tf.image.resize를 통해 사이즈 맞추는걸 배웠다.
# - 원본 논문을 보고 아키텍처를 따라 코드로 구현하는 연습을 처음해봤는데, 쉽진 않아서 시간이 걸렸다. 다음번엔 더 잘할수 있을거란 자신감이 생겼다.
# - 학습 속도의 여러 가지 변수가 있다는 걸 경험했다. 개발환경, GPU유무, 인터넷속도(?)
#     - epoch 1개 당 약 15분 소요됐다.....
# - layer name이 unique해야하는데 자꾸 중복되는 바람에 에러가 자주 떴다. 이를 유의해야한다.
# - for문이 능사는 아니고 경우의 따라 line by line으로 layer를 쌓는게 훨씬 쉽다.
